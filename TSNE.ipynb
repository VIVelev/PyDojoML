# %% [markdown]
# ## Load modules

# %%
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

from dojo.manifold import TSNE
from sklearn.manifold import TSNE as SkTSNE

# %% [markdown]
# ## Prepare the Data

# %%
X1 = np.random.randn(10, 3)
X1 += 3
X1 *= 1

X2 = np.random.rand(10, 3)
X2 += -1
X2 *= 3

X = np.concatenate((X1, X2))
color = ['red'] * 10 + ['blue'] * 10

ax = plt.axes(projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], color=color)
plt.show()

# %% [markdown]
# ## t-SNE

# %%
tsne = TSNE(n_components=2, perplexity=6, n_iter=2000, verbose=True)
Y = tsne.fit_transform(X)
# Out:
# ITERATION: 100   |||   KL divergence: 2.275502988083984e+19
# ITERATION: 200   |||   KL divergence: 2.275502988083984e+19

# %%
plt.scatter(Y[:, 0], Y[:, 1])
plt.show()

# %% [markdown]
# ## *Scikit-learn* t-SNE

# %%
sk_tsne = SkTSNE(n_components=2, perplexity=5, n_iter=2000, verbose=True)
Y = sk_tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 20 samples in 0.000s...
# [t-SNE] Computed neighbors for 20 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 20 / 20
# [t-SNE] Mean sigma: 1.383744
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.738144
# [t-SNE] KL divergence after 1100 iterations: 0.069547

# %%
plt.scatter(Y[:, 0], Y[:, 1])
plt.show()
