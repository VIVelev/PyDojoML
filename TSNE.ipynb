# %% [markdown]
# ## Load modules

# %%
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

from dojo.dimred import TSNE
from sklearn.manifold import TSNE as SkTSNE

# %% [markdown]
# ## Prepare the Data

# %%
X1 = np.random.randn(10, 3)
X1 += 3
X1 *= 1

X2 = np.random.rand(10, 3)
X2 += -1
X2 *= 3

X = np.concatenate((X1, X2))
color = ['red'] * 10 + ['blue'] * 10

ax = plt.axes(projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], color=color)
plt.show()

# %% [markdown]
# ## t-SNE

# %%
tsne = TSNE(n_components=2, perplexity=5, n_iter=2000, verbose=True)
Y = tsne.fit_transform(X)
# Out:
# ITERATION: 100   |||   KL divergence: 9.666614969597182e+22
# ITERATION: 200   |||   KL divergence: 9.666614969597182e+22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9596ee338aaa> in <module>
#       1 tsne = TSNE(n_components=2, perplexity=5, n_iter=2000, verbose=True)
# ----> 2 Y = tsne.fit_transform(X)
#
# ~/Desktop/PyDojoML/dojo/base/preprocessor.py in fit_transform(self, X, y)
#     113         else:
#     114             self.fit(X, y)
# --> 115         return self.transform(X)
#
# ~/Desktop/PyDojoML/dojo/dimred/tsne.py in transform(self, X)
#     147
#     148     def transform(self, X):
# --> 149         return self._optimize(np.zeros((X.shape[0], self.n_components)))
#
# ~/Desktop/PyDojoML/dojo/dimred/tsne.py in _optimize(self, Y)
#     135                 Y[i] -= self.learning_rate * grad# + self.momentum * (prev_Ys[1][i] - prev_Ys[0][i])
#     136
# --> 137             lower_dim_dist = self._get_lower_dim_dist(Y)
#     138             prev_Ys = [prev_Ys[1], Y]
#     139
#
# ~/Desktop/PyDojoML/dojo/dimred/tsne.py in _get_lower_dim_dist(self, Y)
#      94             for j in range(Y.shape[0]):
#      95                 if i != j:
# ---> 96                     Pij = self._lower_dim_sim(Y[i], Y[j], normalize=True, Y=Y, idx=i)
#      97                     Pji = self._lower_dim_sim(Y[i], Y[j], normalize=True, Y=Y, idx=j)
#      98                     table[i, j] = (Pij + Pji) / (2*Y.shape[0])
#
# ~/Desktop/PyDojoML/dojo/dimred/tsne.py in _lower_dim_sim(self, v, w, normalize, Y, idx)
#      59
#      60         if normalize:
# ---> 61             sum_norm = sum(map(lambda x: x[1], self._knn(idx, Y, higher_dim=False)))
#      62             return sim / sum_norm
#      63         else:
#
# ~/Desktop/PyDojoML/dojo/dimred/tsne.py in _knn(self, i, X, higher_dim)
#      71                     distance = self._higher_dim_sim(X[i], X[j], normalize=False)
#      72                 else:
# ---> 73                     distance = self._lower_dim_sim(X[i], X[j], normalize=False)
#      74                 knns.append([j, distance])
#      75
#
# ~/Desktop/PyDojoML/dojo/dimred/tsne.py in _lower_dim_sim(self, v, w, normalize, Y, idx)
#      56         """Computes a (Student) t-Distribution"""
#      57
# ---> 58         sim = (1 + np.linalg.norm(v - w) ** 2) ** -1
#      59
#      60         if normalize:
#
# ~/.local/share/virtualenvs/PyDojoML-qnJvVyMq/lib/python3.7/site-packages/numpy/linalg/linalg.py in norm(x, ord, axis, keepdims)
#    2434     x = asarray(x)
#    2435
# -> 2436     if not issubclass(x.dtype.type, (inexact, object_)):
#    2437         x = x.astype(float)
#    2438
#
# KeyboardInterrupt:

# %%
plt.scatter(Y[:, 0], Y[:, 1])
plt.show()

# %% [markdown]
# ## *Scikit-learn* t-SNE

# %%
sk_tsne = SkTSNE(n_components=2, perplexity=10, n_iter=2000, verbose=True)
Y = sk_tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 19 nearest neighbors...
# [t-SNE] Indexed 20 samples in 0.000s...
# [t-SNE] Computed neighbors for 20 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 20 / 20
# [t-SNE] Mean sigma: 3.867184
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.460396
# [t-SNE] KL divergence after 2000 iterations: 0.245943

# %%
plt.scatter(Y[:, 0], Y[:, 1])
plt.show()
