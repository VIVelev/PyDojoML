# %% [markdown]
# ## Load modules

# %%
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

from dojo.dimred import TSNE
from sklearn.manifold import TSNE as SkTSNE

# %% [markdown]
# ## Prepare the Data

# %%
X1 = np.random.randn(10, 3)
X1 += 3
X1 *= 1

X2 = np.random.rand(10, 3)
X2 += -1
X2 *= 3

X = np.concatenate((X1, X2))
color = ['red'] * 10 + ['blue'] * 10

ax = plt.axes(projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], color=color)
plt.show()

# %% [markdown]
# ## t-SNE

# %%
tsne = TSNE(n_components=2, perplexity=5, n_iter=2000, sigma=3.888362, verbose=True)
Y = tsne.fit_transform(X)
# Out:
# ITERATION: 100   |||   KL divergence: -55.62138841298023
# ITERATION: 200   |||   KL divergence: -76.11522423164337
# ITERATION: 300   |||   KL divergence: -83.35001881033082
# ITERATION: 400   |||   KL divergence: -77.37107764462863
# ITERATION: 500   |||   KL divergence: -86.62350662884694
# ITERATION: 600   |||   KL divergence: -68.95808744705441
# ITERATION: 700   |||   KL divergence: -106.3929400651526
# ITERATION: 800   |||   KL divergence: -89.78220223291574
# ITERATION: 900   |||   KL divergence: -102.53825115661263
# ITERATION: 1000   |||   KL divergence: -104.66540091683687
# ITERATION: 1100   |||   KL divergence: -103.52238627034916
# ITERATION: 1200   |||   KL divergence: -119.09824845334367
# ITERATION: 1300   |||   KL divergence: -115.96762273794933
# ITERATION: 1400   |||   KL divergence: -109.95712527591317
# ITERATION: 1500   |||   KL divergence: -103.267355846645
# ITERATION: 1600   |||   KL divergence: -113.82632303158994
# ITERATION: 1700   |||   KL divergence: -111.86385637501441
# ITERATION: 1800   |||   KL divergence: -118.65907109332801
# ITERATION: 1900   |||   KL divergence: -127.2666048179353
# ITERATION: 2000   |||   KL divergence: -129.86981619685076

# %%
plt.scatter(Y[:, 0], Y[:, 1])
plt.show()

# %% [markdown]
# ## *Scikit-learn* t-SNE

# %%
sk_tsne = SkTSNE(n_components=2, perplexity=10, n_iter=2000, verbose=True)
Y = sk_tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 19 nearest neighbors...
# [t-SNE] Indexed 20 samples in 0.000s...
# [t-SNE] Computed neighbors for 20 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 20 / 20
# [t-SNE] Mean sigma: 3.867184
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.460396
# [t-SNE] KL divergence after 2000 iterations: 0.245943

# %%
plt.scatter(Y[:, 0], Y[:, 1])
plt.show()
