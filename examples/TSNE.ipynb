# %% [markdown]
# ## Load modules

# %%
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

from dojo.manifold import TSNE
from sklearn.manifold import TSNE as SkTSNE

# %% [markdown]
# ## Prepare the Data

# %%
X1 = np.random.randn(10, 3)
X1 += 3
X1 *= 1

X2 = np.random.rand(10, 3)
X2 += -1
X2 *= 3

X = np.concatenate((X1, X2))
color = ['red'] * 10 + ['blue'] * 10

ax = plt.axes(projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], color=color)
plt.show()

# %% [markdown]
# ## t-SNE

# %%
tsne = TSNE(n_components=2, perplexity=10, learning_rate=200, sigma=4, n_iter=2000, verbose=True)
Y = tsne.fit_transform(X)
# Out:
# ITERATION: 100   |||   KL divergence: 4.684037674071947
# ITERATION: 200   |||   KL divergence: 3.3996666015413113
# ITERATION: 300   |||   KL divergence: 3.8107792603868322
# ITERATION: 400   |||   KL divergence: 3.627358798875736
# ITERATION: 500   |||   KL divergence: 4.919445027965322
# ITERATION: 600   |||   KL divergence: 4.8118379197369086
# ITERATION: 700   |||   KL divergence: 5.998675768141986
# ITERATION: 800   |||   KL divergence: 5.985677099870846
# ITERATION: 900   |||   KL divergence: 5.510773108395668
# ITERATION: 1000   |||   KL divergence: 5.477033002513778
# ITERATION: 1100   |||   KL divergence: 5.437224551740455
# ITERATION: 1200   |||   KL divergence: 5.385379142083652
# ITERATION: 1300   |||   KL divergence: 5.315591560111825
# ITERATION: 1400   |||   KL divergence: 5.211441050671127
# ITERATION: 1500   |||   KL divergence: 4.773577766628141
# ITERATION: 1600   |||   KL divergence: 4.839869884558295
# ITERATION: 1700   |||   KL divergence: 4.782537979322529
# ...

# %%
plt.scatter(Y[:, 0], Y[:, 1])
plt.show()

# %% [markdown]
# ## *Scikit-learn* t-SNE

# %%
sk_tsne = SkTSNE(n_components=2, perplexity=10, n_iter=2000, verbose=True)
Y = sk_tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 19 nearest neighbors...
# [t-SNE] Indexed 20 samples in 0.000s...
# [t-SNE] Computed neighbors for 20 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 20 / 20
# [t-SNE] Mean sigma: 3.845512
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.572174
# [t-SNE] KL divergence after 2000 iterations: 0.223550

# %%
plt.scatter(Y[:, 0], Y[:, 1])
plt.show()
